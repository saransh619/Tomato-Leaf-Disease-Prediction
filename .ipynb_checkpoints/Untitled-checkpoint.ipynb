# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#basic cnn
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (128, 128, 3), activation = 'relu'))
# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 10, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)

validation_datagen = ImageDataGenerator(rescale=1./255) #add gareko data new
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('D:/Plant-Leaf-Disease-Prediction/Dataset/train', # relative path from working directoy
                                                 target_size = (128, 128),
                                                 batch_size = 6, class_mode = 'categorical')
valid_set = test_datagen.flow_from_directory('D:/Plant-Leaf-Disease-Prediction/Dataset/val', # relative path from working directoy
                                             target_size = (128, 128), 
                                        batch_size = 3, class_mode = 'categorical')
# Out:
# Found 143 images belonging to 10 classes.
# Found 52 images belonging to 10 classes.

# %%
test_set = test_datagen.flow_from_directory(
        'D:/Plant-Leaf-Disease-Prediction/Dataset/test',
        target_size = (128, 128),
        batch_size = 16,
        class_mode = 'categorical',
        color_mode = "rgb"
)#yo ni add gareko new

labels = (training_set.class_indices)
print(labels)

history = classifier.fit_generator(training_set,
                        steps_per_epoch = 20,
                         epochs = 50,
                         validation_data=valid_set
                         )


  # for testing 
score = classifier.evaluate_generator(test_set)
print('Test Loss:',score[0])
print('Test Accuracy:',score[1])

#add gareko
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

#add gareko
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(50), acc, label='Training Accuracy')
plt.plot(range(50), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(range(50), loss, label='Training Loss')
plt.plot(range(50), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

classifier_json=classifier.to_json()
with open("model1.json", "w") as json_file:
    json_file.write(classifier_json)
# serialize weights to HDF5
    classifier.save_weights("my_model_weights.h5")
    classifier.save("model.h5")
    print("Saved model to disk")
# Out:
# Found 0 images belonging to 0 classes.
# {'Tomato - Bacterial_spot': 0, 'Tomato - Early_blight': 1, 'Tomato - Healthy': 2, 'Tomato - Late_blight': 3, 'Tomato - Leaf_Mold': 4, 'Tomato - Septoria_leaf_spot': 5, 'Tomato - Target_Spot': 6, 'Tomato - Tomato_Yellow_Leaf_Curl_Virus': 7, 'Tomato - Tomato_mosaic_virus': 8, 'Tomato - Two-spotted_spider_mite': 9}
# Epoch 1/50
# 20/20 [==============================] - 4s 154ms/step - batch: 9.5000 - size: 5.9500 - loss: 2.4510 - accuracy: 0.1261 - val_loss: 2.2681 - val_accuracy: 0.1923
# Epoch 2/50
# 20/20 [==============================] - 3s 148ms/step - batch: 9.5000 - size: 5.9500 - loss: 2.2438 - accuracy: 0.1597 - val_loss: 2.3673 - val_accuracy: 0.1154
# Epoch 3/50
# 20/20 [==============================] - 3s 158ms/step - batch: 9.5000 - size: 6.0000 - loss: 2.1467 - accuracy: 0.1667 - val_loss: 2.0927 - val_accuracy: 0.1923
# Epoch 4/50
# 20/20 [==============================] - 3s 154ms/step - batch: 9.5000 - size: 5.9000 - loss: 2.1975 - accuracy: 0.1610 - val_loss: 2.1273 - val_accuracy: 0.1923
# Epoch 5/50
# 20/20 [==============================] - 3s 157ms/step - batch: 9.5000 - size: 6.0000 - loss: 1.9266 - accuracy: 0.3000 - val_loss: 2.2160 - val_accuracy: 0.2500
# Epoch 6/50
# 20/20 [==============================] - 3s 162ms/step - batch: 9.5000 - size: 5.9500 - loss: 1.6079 - accuracy: 0.4706 - val_loss: 1.7483 - val_accuracy: 0.4808
# Epoch 7/50
# 20/20 [==============================] - 3s 148ms/step - batch: 9.5000 - size: 5.9500 - loss: 1.3480 - accuracy: 0.5126 - val_loss: 2.4021 - val_accuracy: 0.3654
# Epoch 8/50
# 20/20 [==============================] - 3s 154ms/step - batch: 9.5000 - size: 5.9500 - loss: 1.5885 - accuracy: 0.4958 - val_loss: 2.1147 - val_accuracy: 0.4423
# Epoch 9/50
# 20/20 [==============================] - 3s 154ms/step - batch: 9.5000 - size: 6.0000 - loss: 1.0984 - accuracy: 0.5917 - val_loss: 1.8675 - val_accuracy: 0.4423
# Epoch 10/50
# 20/20 [==============================] - 3s 150ms/step - batch: 9.5000 - size: 5.9500 - loss: 1.0171 - accuracy: 0.6303 - val_loss: 2.1938 - val_accuracy: 0.5577
# Epoch 11/50
# 20/20 [==============================] - 3s 164ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.8079 - accuracy: 0.7647 - val_loss: 2.2280 - val_accuracy: 0.5385
# Epoch 12/50
# 20/20 [==============================] - 3s 150ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.7920 - accuracy: 0.6975 - val_loss: 3.1770 - val_accuracy: 0.5385
# Epoch 13/50
# 20/20 [==============================] - 3s 151ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.7423 - accuracy: 0.7899 - val_loss: 2.7479 - val_accuracy: 0.5192
# Epoch 14/50
# 20/20 [==============================] - 3s 154ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.4858 - accuracy: 0.8739 - val_loss: 2.7719 - val_accuracy: 0.5577
# Epoch 15/50
# 20/20 [==============================] - 3s 150ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.3982 - accuracy: 0.9333 - val_loss: 3.0519 - val_accuracy: 0.5000
# Epoch 16/50
# 20/20 [==============================] - 3s 158ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.5700 - accuracy: 0.8151 - val_loss: 2.9303 - val_accuracy: 0.5192
# Epoch 17/50
# 20/20 [==============================] - 3s 149ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.6627 - accuracy: 0.7983 - val_loss: 2.1968 - val_accuracy: 0.5000
# Epoch 18/50
# 20/20 [==============================] - 3s 147ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.3984 - accuracy: 0.8655 - val_loss: 2.2949 - val_accuracy: 0.5577
# Epoch 19/50
# 20/20 [==============================] - 3s 150ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.3994 - accuracy: 0.9076 - val_loss: 2.7289 - val_accuracy: 0.6346
# Epoch 20/50
# 20/20 [==============================] - 3s 153ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.4593 - accuracy: 0.8571 - val_loss: 2.5143 - val_accuracy: 0.6154
# Epoch 21/50
# 20/20 [==============================] - 3s 156ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.2999 - accuracy: 0.8917 - val_loss: 2.4470 - val_accuracy: 0.6346
# Epoch 22/50
# 20/20 [==============================] - 3s 156ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1443 - accuracy: 0.9916 - val_loss: 3.3562 - val_accuracy: 0.5769
# Epoch 23/50
# 20/20 [==============================] - 3s 147ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.2607 - accuracy: 0.9244 - val_loss: 3.4251 - val_accuracy: 0.5192
# Epoch 24/50
# 20/20 [==============================] - 3s 156ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.2210 - accuracy: 0.9328 - val_loss: 2.2309 - val_accuracy: 0.5192
# Epoch 25/50
# 20/20 [==============================] - 3s 147ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.2272 - accuracy: 0.9328 - val_loss: 2.6977 - val_accuracy: 0.6538
# Epoch 26/50
# 20/20 [==============================] - 3s 159ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.1803 - accuracy: 0.9333 - val_loss: 2.8626 - val_accuracy: 0.4615
# Epoch 27/50
# 20/20 [==============================] - 3s 148ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.2659 - accuracy: 0.9244 - val_loss: 3.0940 - val_accuracy: 0.5769
# Epoch 28/50
# 20/20 [==============================] - 3s 143ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1933 - accuracy: 0.9328 - val_loss: 3.0420 - val_accuracy: 0.5000
# Epoch 29/50
# 20/20 [==============================] - 3s 155ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1298 - accuracy: 0.9748 - val_loss: 3.0761 - val_accuracy: 0.5962
# Epoch 30/50
# 20/20 [==============================] - 3s 147ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1762 - accuracy: 0.9244 - val_loss: 2.9438 - val_accuracy: 0.5962
# Epoch 31/50
# 20/20 [==============================] - 3s 161ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1391 - accuracy: 0.9412 - val_loss: 3.4889 - val_accuracy: 0.4808
# Epoch 32/50
# 20/20 [==============================] - 4s 202ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.2695 - accuracy: 0.9412 - val_loss: 3.1086 - val_accuracy: 0.5000
# Epoch 33/50
# 20/20 [==============================] - 4s 182ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.1360 - accuracy: 0.9500 - val_loss: 3.8497 - val_accuracy: 0.5385
# Epoch 34/50
# 20/20 [==============================] - 3s 154ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1248 - accuracy: 0.9748 - val_loss: 3.5861 - val_accuracy: 0.5385
# Epoch 35/50
# 20/20 [==============================] - 3s 162ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.2981 - accuracy: 0.9244 - val_loss: 3.5713 - val_accuracy: 0.5385
# Epoch 36/50
# 20/20 [==============================] - 3s 175ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.2321 - accuracy: 0.9244 - val_loss: 3.7648 - val_accuracy: 0.5577
# Epoch 37/50
# 20/20 [==============================] - 3s 161ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1628 - accuracy: 0.9412 - val_loss: 3.1292 - val_accuracy: 0.5962
# Epoch 38/50
# 20/20 [==============================] - 3s 166ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.2839 - accuracy: 0.8833 - val_loss: 3.5691 - val_accuracy: 0.5577
# Epoch 39/50
# 20/20 [==============================] - 3s 150ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1511 - accuracy: 0.9412 - val_loss: 3.7876 - val_accuracy: 0.5769
# Epoch 40/50
# 20/20 [==============================] - 3s 156ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1205 - accuracy: 0.9412 - val_loss: 3.1760 - val_accuracy: 0.6346
# Epoch 41/50
# 20/20 [==============================] - 3s 154ms/step - batch: 9.5000 - size: 5.9000 - loss: 0.0868 - accuracy: 0.9576 - val_loss: 3.3619 - val_accuracy: 0.5577
# Epoch 42/50
# 20/20 [==============================] - 3s 145ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.0376 - accuracy: 0.9917 - val_loss: 4.1004 - val_accuracy: 0.5192
# Epoch 43/50
# 20/20 [==============================] - 3s 156ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.0450 - accuracy: 0.9917 - val_loss: 4.3032 - val_accuracy: 0.5385 0.0389 - accuracy:
# Epoch 44/50
# 20/20 [==============================] - 3s 151ms/step - batch: 9.5000 - size: 5.9000 - loss: 0.0578 - accuracy: 0.9831 - val_loss: 4.5196 - val_accuracy: 0.5577
# Epoch 45/50
# 20/20 [==============================] - 4s 177ms/step - batch: 9.5000 - size: 6.0000 - loss: 0.0684 - accuracy: 0.9667 - val_loss: 3.6346 - val_accuracy: 0.5000
# Epoch 46/50
# 20/20 [==============================] - 3s 161ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1323 - accuracy: 0.9580 - val_loss: 4.2932 - val_accuracy: 0.5962
# Epoch 47/50
# 20/20 [==============================] - 3s 148ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1557 - accuracy: 0.9328 - val_loss: 2.8257 - val_accuracy: 0.6154
# Epoch 48/50
# 20/20 [==============================] - 3s 157ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1226 - accuracy: 0.9664 - val_loss: 3.6113 - val_accuracy: 0.5962
# Epoch 49/50
# 20/20 [==============================] - 3s 147ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.1464 - accuracy: 0.9328 - val_loss: 3.1905 - val_accuracy: 0.5192
# Epoch 50/50
# 20/20 [==============================] - 3s 150ms/step - batch: 9.5000 - size: 5.9500 - loss: 0.0605 - accuracy: 0.9664 - val_loss: 3.7184 - val_accuracy: 0.5577
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18796/4257659185.py in <module>
#      18
#      19   # for testing
# ---> 20 score = classifier.evaluate_generator(test_set)
#      21 print('Test Loss:',score[0])
#      22 print('Test Accuracy:',score[1])
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py in evaluate_generator(self, generator, steps, callbacks, max_queue_size, workers, use_multiprocessing, verbose)
#    1276     self._check_call_args('evaluate_generator')
#    1277
# -> 1278     return self.evaluate(
#    1279         generator,
#    1280         steps=steps,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_v1.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     901
#     902     func = self._select_training_loop(x)
# --> 903     return func.evaluate(
#     904         self,
#     905         x=x,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator_v1.py in evaluate(self, model, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#     607     model._validate_or_infer_batch_size(batch_size, steps, x)
#     608     training_utils_v1.check_generator_arguments(y, sample_weight)
# --> 609     return evaluate_generator(
#     610         model,
#     611         x,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_generator_v1.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     289         break
#     290
# --> 291     aggregator.finalize()
#     292     results = aggregator.results
#     293     epoch_logs = cbks.make_logs(model, epoch_logs, results, mode)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training_utils_v1.py in finalize(self)
#     140   def finalize(self):
#     141     if not self.results:
# --> 142       raise ValueError('Empty training data.')
#     143     self.results[0] /= (self.num_samples or self.steps)
#     144
#
# ValueError: Empty training data.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

#add gareko
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(50), acc, label='Training Accuracy')
plt.plot(range(50), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.subplot(1, 2, 2)
plt.plot(range(50), loss, label='Training Loss')
plt.plot(range(50), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
